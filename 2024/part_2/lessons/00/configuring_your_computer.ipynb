# %% [markdown]
# # Lesson 0: Setting up computing resources

# %% [markdown]
# To set up your computer, follow [the instructions for part 1 of the workshop](https://justinbois.github.io/dd-pol/2024/part_1/lessons/00/configuring_your_computer.html).
